# %% [markdown]
# # Mi primer acercamiento al mundo crypto 💹
#
# El 12 de marzo de 2026 me encotraba hablando con unos amigos en la sala de mi casa y entre los temas que conversamos, surgió uno que captaría mi atención.
#
# <center><img src = "img/img1.png" width = "450" height = "310"><center>

# %% [markdown]
# Pues resulta que ellos que habían invertido en una criptomoneda llamada XRP, también me dijeron que podía ser esta una de las monedas del futuro y que podía ser una buena inversión a largo plazo. Yo nunca he sido un gran entuciasta de este tipo de cosas pero lo que si me entuciasma es la Ciencia de Datos y particularmente tengo un amor especial por las series de tiempo.
#
# Así es como nace este proyecto en el cual me dispuse a invertigar el comportamiento de XRP, pero para ello necestitaba datos para analizar es por eso que me conecte a la api de Yahoo Finace para extraer la infomacion puedes ver como lo hice en el scrip de python de este mismo directorio
#
# Acompañame en este viaje de investigación y vamos a por todas 🛫
